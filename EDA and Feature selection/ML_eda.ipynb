# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /Users/malavikavenkatesh/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
data = pd.read_csv("European_bank_marketing.csv")

# %%
print(data.shape)
print(data.head())
print(data.dtypes)
# Out:
# (41188, 22)
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon  ...    999         0  nonexistent           1.1
# 1   may         mon  ...    999         0  nonexistent           1.1
# 2   may         mon  ...    999         0  nonexistent           1.1
# 3   may         mon  ...    999         0  nonexistent           1.1
# 4   may         mon  ...    999         0  nonexistent           1.1
#
#   cons.price.idx  cons.conf.idx  euribor3m  nr.employed  term_deposit  \
# ...

# %%
print(data.isnull().sum())
# Out:
# age                  0
# job                  0
# marital              0
# education            0
# default              0
# housing              0
# loan                 0
# contact              0
# month                0
# day_of_week          0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx       0
# cons.conf.idx        0
# euribor3m            0
# nr.employed          0
# term_deposit         0
# Ethnicity_African    0
# dtype: int64

# %%
data["job"].value_counts()
# Out:
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64

# %%
data["marital"].value_counts()
# Out:
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: marital, dtype: int64

# %%
data["education"].value_counts()
# Out:
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: education, dtype: int64

# %%
corr = data.corr()
sns.heatmap(corr, cmap="YlGnBu")
# Out:
# <ipython-input-19-783b98bb87c0>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
# <AxesSubplot:>

# %%
data.hist(figsize=(12, 8))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'duration'}>,
#         <AxesSubplot:title={'center':'campaign'}>],
#        [<AxesSubplot:title={'center':'pdays'}>,
#         <AxesSubplot:title={'center':'previous'}>,
#         <AxesSubplot:title={'center':'emp.var.rate'}>],
#        [<AxesSubplot:title={'center':'cons.price.idx'}>,
#         <AxesSubplot:title={'center':'cons.conf.idx'}>,
#         <AxesSubplot:title={'center':'euribor3m'}>],
#        [<AxesSubplot:title={'center':'nr.employed'}>,
#         <AxesSubplot:title={'center':'term_deposit'}>,
#         <AxesSubplot:title={'center':'Ethnicity_African'}>]], dtype=object)

# %%
sns.scatterplot(x='age', y='duration', data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='duration'>

# %%
sns.boxplot(x='marital', y='duration', data=data)
# Out:
# <AxesSubplot:xlabel='marital', ylabel='duration'>

# %%
sns.pairplot(data.select_dtypes(include='number'))

# %%
sns.countplot(x='job', data=data)
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x='marital', data=data)
# Out:
# <AxesSubplot:xlabel='marital', ylabel='count'>

# %%
sns.countplot(x='education', data=data)
plt.xticks(rotation=45)
plt.show()

# %%
sns.distplot(data['duration'])
# Out:
# /Users/malavikavenkatesh/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='duration', ylabel='Density'>

# %%
sns.violinplot(x='job', y='duration', data=data)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.title("To check the percentge of ppl that have taken term deposit and others", color = 'green')
data.term_deposit.value_counts(normalize=True).plot.pie(autopct='%1.2f%%')
plt.show()

# %%
term_1 = data[data.term_deposit==1]
term_0 = data[data.term_deposit==0]

# %%
data.head(1)
# Out:
#    age        job  marital education default housing loan    contact month  \
# 0   56  housemaid  married  basic.4y      no      no   no  telephone   may
#
#   day_of_week  ...  pdays  previous     poutcome  emp.var.rate cons.price.idx  \
# 0         mon  ...    999         0  nonexistent           1.1         93.994
#
#    cons.conf.idx  euribor3m  nr.employed  term_deposit  Ethnicity_African
# 0          -36.4      4.857       5191.0             0                  0
#
# [1 rows x 22 columns]

# %%
plt.figure(figsize = [10,5])
sns.set(style="darkgrid")
sns.distplot(data.age, color = 'magenta');
plt.title("Distribution of age", fontdict = {'fontsize': 15, 'fontweight': 20, 'color' : 'brown'})
plt.show()
# Out:
# /Users/malavikavenkatesh/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
def distribution(col, label_rotation = True,horizontal_layout= True, hue = None):
    if(horizontal_layout):
        fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
    else:
        fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(12,14))
    
    s1 = sns.countplot(ax = ax1, data = term_1, x= term_1[col], order=term_1[col].value_counts().index,hue = hue,palette='magma') 
    if(label_rotation):
        s1.set_xticklabels(s1.get_xticklabels(),rotation = 90)
    ax1.set_xlabel('%s' %col)
    ax1.set_ylabel("Count")
    plt.xticks(rotation=90)

    
    ax1.set_title('Distribution of '+ '%s' %col +' for leads who have taken the term deposit', fontsize=10)


    
    s2 = sns.countplot(ax = ax2, data = term_0, x= term_0[col], order=term_0[col].value_counts().index,hue = hue,palette='magma') 
    #s2=sns.countplot(ax=ax2,x=nondefaulters[var], data=nondefaulters, order= nondefaulters[var].value_counts().index,)
    if(label_rotation):
        s2.set_xticklabels(s2.get_xticklabels(),rotation=45)
    ax2.set_xlabel('%s' %col)
    ax2.set_ylabel("Count")
    plt.xticks(rotation=90)

    ax2.set_title('Distribution of '+ '%s' %col +' for leads who have not taken the term deposit', fontsize=10)
    plt.show()

# %%
distribution('job', hue='term_deposit')

# %%
distribution('marital', hue='term_deposit')

# %%
distribution('education', hue='term_deposit')

# %%
bins = [20, 30, 40, 50, 60, 70, 80]
labels = ['20-29', '30-39', '40-49', '50-59', '60-69', '70-79']
data['age'] = pd.cut(data['age'], bins=bins, labels=labels)
print(data.head())
# Out:
#      age        job  marital    education  default housing loan    contact  \
# 0  50-59  housemaid  married     basic.4y       no      no   no  telephone
# 1  50-59   services  married  high.school  unknown      no   no  telephone
# 2  30-39   services  married  high.school       no     yes   no  telephone
# 3  30-39     admin.  married     basic.6y       no      no   no  telephone
# 4  50-59   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon  ...    999         0  nonexistent           1.1
# 1   may         mon  ...    999         0  nonexistent           1.1
# 2   may         mon  ...    999         0  nonexistent           1.1
# 3   may         mon  ...    999         0  nonexistent           1.1
# 4   may         mon  ...    999         0  nonexistent           1.1
#
#   cons.price.idx  cons.conf.idx  euribor3m  nr.employed  term_deposit  \
# ...

# %%
data["age"].value_counts()
# Out:
# 30-39    16385
# 40-49    10240
# 20-29     7243
# 50-59     6270
# 60-69      488
# 70-79      303
# Name: age, dtype: int64

# %%
data.age.value_counts(normalize=True).plot.pie()
# Out:
# <AxesSubplot:ylabel='age'>

# %%
data.job.value_counts(normalize=True).plot.pie()
# Out:
# <AxesSubplot:ylabel='job'>

# %%
data.marital.value_counts(normalize=True).plot.pie()
# Out:
# <AxesSubplot:ylabel='marital'>

# %%
data.education.value_counts(normalize=True).plot.pie()
# Out:
# <AxesSubplot:ylabel='education'>

# %%
age_contact = pd.crosstab(data['age'], data['contact'])
age_contact.plot(kind='bar', stacked=True)
plt.xlabel("Age Category")
plt.ylabel("Count")
plt.title("Distribution of Contact Types by Age Categories")

plt.show()

# %%
prev_contact = pd.crosstab(data['previous'], data['poutcome'])
prev_contact.plot(kind='bar', stacked=True)
plt.xlabel("Previous contact")
plt.ylabel("Count")
plt.title("Distribution of previous contacts and the outcomes")

plt.show()

# %%
plt.figure(figsize = [10,5])
sns.set(style="darkgrid")
sns.distplot(data.duration, color = 'magenta');
plt.title("Distribution of duration of the call", fontdict = {'fontsize': 15, 'fontweight': 20, 'color' : 'brown'})
plt.show()
# Out:
# /Users/malavikavenkatesh/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['duration'] = data['duration'] / 60

# %%
data["duration"].value_counts()
# Out:
# 1.500000     170
# 1.416667     170
# 2.266667     168
# 1.216667     167
# 2.066667     164
#             ...
# 26.150000      1
# 17.550000      1
# 21.050000      1
# 19.483333      1
# 31.133333      1
# Name: duration, Length: 1544, dtype: int64

# %%
print(data['duration'].max())
# Out:
# 81.96666666666667

# %%
#after binning
data["duration"].value_counts()
# Out:
# 5-10     7740
# 11-15    2183
# 16-20     768
# 21-25     307
# 26-30     105
# 31-35      56
# 36-40      14
# 41-45      13
# 51-55       6
# 56-60       4
# 46-50       3
# 61-65       3
# 66-70       1
# 81-85       1
# 71-75       0
# 76-80       0
# Name: duration, dtype: int64

# %%
age_contact = pd.crosstab(data['duration'], data['contact'])
age_contact.plot(kind='bar', stacked=True)
plt.xlabel("Duration Category")
plt.ylabel("Count")
plt.title("Distribution of contatc based on duration")

plt.show()

# %%
age_contact = pd.crosstab(data['duration'], data['age'])
age_contact.plot(kind='bar', stacked=True)
plt.xlabel("Duration Category")
plt.ylabel("Count")
plt.title("Distribution of age based on duration")

plt.show()

# %%
import plotly.express as px
fig = px.box(term_1, x="job", y="loan", color='marital',
             title="job vs loan") 
fig.show()
# Out:
# <div>                            <div id="94adb8b5-336a-464b-8d62-c704b3165680" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94adb8b5-336a-464b-8d62-c704b3165680")) {                    Plotly.newPlot(                        "94adb8b5-336a-464b-8d62-c704b3165680",                        [{"alignmentgroup":"True","hovertemplate":"marital=divorced<br>job=%{x}<br>loan=%{y}<extra></extra>","legendgroup":"divorced","marker":{"color":"#636efa"},"name":"divorced","notched":false,"offsetgroup":"divorced","orientation":"v","showlegend":true,"x":["blue-collar","admin.","entrepreneur","services","unemployed","services","blue-collar","blue-collar","admin.","admin.","services","services","technician","admin.","blue-collar","admin.","services","admin.","blue-c
# ...

# %%
def stat_chart(feature,label_rotation=True,horizontal_layout=True):
    temp_data = data[feature].value_counts()
    df1 = pd.DataFrame({feature: temp_data.index,'count': temp_data.values})

    # percentage of term=1 
    per = data[[feature, 'term_deposit']].groupby([feature],as_index=False).mean()
    per.sort_values(by='term_deposit', ascending=False, inplace=True)
    
    if(horizontal_layout):
        fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
    else:
        fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(12,14))
    sns.set_color_codes("pastel")
    s = sns.barplot(ax=ax1, x = feature, y="count",data=df1)
    if(label_rotation):
        s.set_xticklabels(s.get_xticklabels(),rotation=90)
    
    s = sns.barplot(ax=ax2, x = feature, y='term_deposit', order=per[feature], data=per)
    if(label_rotation):
        s.set_xticklabels(s.get_xticklabels(),rotation=90)
    plt.ylabel('Percentage', fontsize=10)
    plt.tick_params(axis='both', which='major', labelsize=10)

    plt.show();

# %%
stat_chart('job')

# %%
stat_chart('marital')

# %%
stat_chart('education')

# %%
stat_chart('housing')

# %%
stat_chart('loan')
